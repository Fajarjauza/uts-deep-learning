# %% [markdown]
# # 1. Import Library

# %%
import pandas as pd
import numpy as np
import random
import re
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # 2. Load Dataset

# %%
train_df = pd.read_csv('/content/train.csv')
test_df = pd.read_csv('/content/test.csv')

train_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# Cek bentuk dataset:

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (7613, 5)
# (3263, 4)

# %% [markdown]
# Cek kolom:

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %% [markdown]
# # 3. Exploratory Data Analysis Sederhana

# %%
train_df['target'].value_counts()
# Out:
# target
# 0    4342
# 1    3271
# Name: count, dtype: int64

# %% [markdown]
# Visualisasi distribusi label:

# %%
sns.countplot(data=train_df, x='target')
plt.title('Distribusi Label Target')
plt.show()

# %% [markdown]
# Cek contoh tweet disaster:

# %%
train_df[train_df['target'] == 1]['text'].head(10)
# Out:
# 0    Our Deeds are the Reason of this #earthquake M...
# 1               Forest fire near La Ronge Sask. Canada
# 2    All residents asked to 'shelter in place' are ...
# 3    13,000 people receive #wildfires evacuation or...
# 4    Just got sent this photo from Ruby #Alaska as ...
# 5    #RockyFire Update => California Hwy. 20 closed...
# 6    #flood #disaster Heavy rain causes flash flood...
# 7    I'm on top of the hill and I can see a fire in...
# 8    There's an emergency evacuation happening now ...
# 9    I'm afraid that the tornado is coming to our a...
# Name: text, dtype: object

# %% [markdown]
# Cek contoh tweet non-disaster:

# %%
train_df[train_df['target'] == 0]['text'].head(10)
# Out:
# 15                  What's up man?
# 16                   I love fruits
# 17                Summer is lovely
# 18               My car is so fast
# 19    What a goooooooaaaaaal!!!!!!
# 20          this is ridiculous....
# 21               London is cool ;)
# 22                     Love skiing
# 23           What a wonderful day!
# 24                        LOOOOOOL
# Name: text, dtype: object

# %% [markdown]
# # 4. Text Preprocessing
# Preprocessing yang dilakukan:
# *   Lowercasing
# *   Menghapus URL
# *   Menghapus mention
# *   Menghapus hashtag symbol #, tapi isi katanya tetap dipakai
# *   Menghapus karakter non-huruf
# *   Menghapus spasi berlebih

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %% [markdown]
# Terapkan ke dataset:

# %%
train_df['clean_text'] = train_df['text'].apply(clean_text)
test_df['clean_text'] = test_df['text'].apply(clean_text)

train_df[['text', 'clean_text', 'target']].head()
# Out:
#                                                 text  \
# 0  Our Deeds are the Reason of this #earthquake M...
# 1             Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are ...
# 3  13,000 people receive #wildfires evacuation or...
# 4  Just got sent this photo from Ruby #Alaska as ...
#
#                                           clean_text  target
# 0  our deeds are the reason of this earthquake ma...       1
# 1              forest fire near la ronge sask canada       1
# 2  all residents asked to shelter in place are be...       1
# 3  people receive wildfires evacuation orders in ...       1
# 4  just got sent this photo from ruby alaska as s...       1

# %% [markdown]
# # 5. Split Data Train dan Validation

# %%
X = train_df['clean_text']
y = train_df['target']

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.2,
    random_state=SEED,
    stratify=y
)

# %% [markdown]
# Cek ukuran data:

# %%
print("Train size:", X_train.shape)
print("Validation size:", X_val.shape)
# Out:
# Train size: (6090,)
# Validation size: (1523,)

# %% [markdown]
# # **6. Baseline 1 — TF-IDF Unigram + LogistiRegression**
#
# ---

# %% [markdown]
# # 6.1 TF-IDF Unigram

# %%
tfidf_uni = TfidfVectorizer(
    ngram_range=(1, 1),
    max_features=10000
)

X_train_uni = tfidf_uni.fit_transform(X_train)
X_val_uni = tfidf_uni.transform(X_val)

# %%
# Tuning sederhana Logistic Regression

for C in [0.1, 1, 10]:
    model = LogisticRegression(max_iter=1000, C=C, random_state=SEED)
    model.fit(X_train_uni, y_train)
    pred = model.predict(X_val_uni)
    print("C:", C, "F1:", f1_score(y_val, pred))
# Out:
# C: 0.1 F1: 0.6429277942631059
# C: 1 F1: 0.7722772277227723
# C: 10 F1: 0.7627251370399374

# %%
lr_model = LogisticRegression(max_iter=1000, C=1, random_state=SEED)
lr_model.fit(X_train_uni, y_train)
# Out:
# LogisticRegression(C=1, max_iter=1000, random_state=42)

# %% [markdown]
# # 6.2 Training Logistic Regression

# %%
start_train = time.time()

lr_model = LogisticRegression(max_iter=1000, random_state=SEED)
lr_model.fit(X_train_uni, y_train)

end_train = time.time()
lr_train_time = end_train - start_train

# %% [markdown]
# # 6.3 Evaluasi Logistic Regression

# %%
start_pred = time.time()

y_pred_lr = lr_model.predict(X_val_uni)

end_pred = time.time()
lr_inference_time = end_pred - start_pred

# %%
lr_accuracy = accuracy_score(y_val, y_pred_lr)
lr_precision = precision_score(y_val, y_pred_lr)
lr_recall = recall_score(y_val, y_pred_lr)
lr_f1 = f1_score(y_val, y_pred_lr)

print("Logistic Regression Results")
print("Accuracy:", lr_accuracy)
print("Precision:", lr_precision)
print("Recall:", lr_recall)
print("F1-score:", lr_f1)
print("Training Time:", lr_train_time)
print("Inference Time:", lr_inference_time)
# Out:
# Logistic Regression Results
# Accuracy: 0.8187787261982928
# Precision: 0.8387096774193549
# Recall: 0.7155963302752294
# F1-score: 0.7722772277227723
# Training Time: 0.20555973052978516
# Inference Time: 0.004449367523193359

# %% [markdown]
# Classification report:

# %%
print(classification_report(y_val, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       869
#            1       0.84      0.72      0.77       654
#
#     accuracy                           0.82      1523
#    macro avg       0.82      0.81      0.81      1523
# weighted avg       0.82      0.82      0.82      1523

# %% [markdown]
# # **7. Baseline 2 — TF-IDF Unigram + Bigram + Linear SVM**
#
# ---

# %% [markdown]
# # 7.1 TF-IDF Unigram + Bigram

# %%
tfidf_bi = TfidfVectorizer(
    ngram_range=(1, 2),
    max_features=15000
)

X_train_bi = tfidf_bi.fit_transform(X_train)
X_val_bi = tfidf_bi.transform(X_val)

# %%
# Tuning sederhana Linear SVM

for C in [0.1, 1, 10]:
    model = LinearSVC(C=C)
    model.fit(X_train_bi, y_train)
    pred = model.predict(X_val_bi)
    print("C:", C, "F1:", f1_score(y_val, pred))
# Out:
# C: 0.1 F1: 0.7636669470142977
# C: 1 F1: 0.759592795614722
# C: 10 F1: 0.7293404094010614

# %%
svm_model = LinearSVC(C=0.1)
svm_model.fit(X_train_bi, y_train)
# Out:
# LinearSVC(C=0.1)

# %% [markdown]
# # 7.2 Training Linear SVM

# %%
start_train = time.time()

svm_model = LinearSVC()
svm_model.fit(X_train_bi, y_train)

end_train = time.time()
svm_train_time = end_train - start_train

# %% [markdown]
# # 7.3 Evaluasi Linear SVM

# %%
start_pred = time.time()

y_pred_svm = svm_model.predict(X_val_bi)

end_pred = time.time()
svm_inference_time = end_pred - start_pred

# %%
svm_accuracy = accuracy_score(y_val, y_pred_svm)
svm_precision = precision_score(y_val, y_pred_svm)
svm_recall = recall_score(y_val, y_pred_svm)
svm_f1 = f1_score(y_val, y_pred_svm)

print("Linear SVM Results")
print("Accuracy:", svm_accuracy)
print("Precision:", svm_precision)
print("Recall:", svm_recall)
print("F1-score:", svm_f1)
print("Training Time:", svm_train_time)
print("Inference Time:", svm_inference_time)
# Out:
# Linear SVM Results
# Accuracy: 0.7984241628365069
# Precision: 0.7784911717495987
# Recall: 0.7415902140672783
# F1-score: 0.759592795614722
# Training Time: 0.0359797477722168
# Inference Time: 0.001153707504272461

# %% [markdown]
# Classification report:

# %%
print(classification_report(y_val, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83       869
#            1       0.78      0.74      0.76       654
#
#     accuracy                           0.80      1523
#    macro avg       0.80      0.79      0.79      1523
# weighted avg       0.80      0.80      0.80      1523

# %% [markdown]
# # **8. Baseline 3 — TF-IDF Unigram + Bigram + Multinomial Naive Bayes**
#
# ---

# %%
start_train = time.time()

nb_model = MultinomialNB()
nb_model.fit(X_train_bi, y_train)

end_train = time.time()
nb_train_time = end_train - start_train

# %%
# Tuning sederhana Multinomial Naive Bayes

for alpha in [0.1, 0.5, 1.0]:
    model = MultinomialNB(alpha=alpha)
    model.fit(X_train_bi, y_train)
    pred = model.predict(X_val_bi)
    print("alpha:", alpha, "F1:", f1_score(y_val, pred))
# Out:
# alpha: 0.1 F1: 0.7562604340567612
# alpha: 0.5 F1: 0.76
# alpha: 1.0 F1: 0.7511071744906997

# %%
nb_model = MultinomialNB(alpha=0.5)
nb_model.fit(X_train_bi, y_train)
# Out:
# MultinomialNB(alpha=0.5)

# %% [markdown]
# Prediksi:

# %%
start_pred = time.time()

y_pred_nb = nb_model.predict(X_val_bi)

end_pred = time.time()
nb_inference_time = end_pred - start_pred

# %% [markdown]
# Evaluasi:

# %%
nb_accuracy = accuracy_score(y_val, y_pred_nb)
nb_precision = precision_score(y_val, y_pred_nb)
nb_recall = recall_score(y_val, y_pred_nb)
nb_f1 = f1_score(y_val, y_pred_nb)

print("Multinomial Naive Bayes Results")
print("Accuracy:", nb_accuracy)
print("Precision:", nb_precision)
print("Recall:", nb_recall)
print("F1-score:", nb_f1)
print("Training Time:", nb_train_time)
print("Inference Time:", nb_inference_time)
# Out:
# Multinomial Naive Bayes Results
# Accuracy: 0.8187787261982928
# Precision: 0.8810483870967742
# Recall: 0.6681957186544343
# F1-score: 0.76
# Training Time: 0.007203578948974609
# Inference Time: 0.0019981861114501953

# %% [markdown]
# # 9. Deep Learning — Embedding + **LSTM**
#
# ---

# %% [markdown]
# # 10. Import Library Deep Learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # 11. Tokenization dan Padding

# %%
max_words = 10000
max_len = 50

tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_val_seq = tokenizer.texts_to_sequences(X_val)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_len, padding='post', truncating='post')
X_val_pad = pad_sequences(X_val_seq, maxlen=max_len, padding='post', truncating='post')

# %% [markdown]
# # 12. Model LSTM

# %%
lstm_model = Sequential([
    Embedding(input_dim=max_words, output_dim=128, input_length=max_len),
    LSTM(64, return_sequences=False),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# Compile model:

# %%
lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Ringkasan model:

# %%
lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 13. Training LSTM

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
start_train = time.time()

history = lstm_model.fit(
    X_train_pad,
    y_train,
    validation_data=(X_val_pad, y_val),
    epochs=10,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

end_train = time.time()
lstm_train_time = end_train - start_train
# Out:
# Epoch 1/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - accuracy: 0.5634 - loss: 0.6870 - val_accuracy: 0.5706 - val_loss: 0.6842
# Epoch 2/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 0.5701 - loss: 0.6847 - val_accuracy: 0.5706 - val_loss: 0.6846
# Epoch 3/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 114ms/step - accuracy: 0.5703 - loss: 0.6841 - val_accuracy: 0.5706 - val_loss: 0.6841
# Epoch 4/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 29s 50ms/step - accuracy: 0.5700 - loss: 0.6843 - val_accuracy: 0.5706 - val_loss: 0.6841
# Epoch 5/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.5703 - loss: 0.6845 - val_accuracy: 0.5706 - val_loss: 0.6835
# Epoch 6/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.5701 - loss: 0.6841 - val_accuracy: 0.5706 - val_loss: 0.6833
# Epoch 7/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.5700 - loss: 0.6838 - val_accuracy: 0.5706 - val_loss: 0.6836
# Epoch 8/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.5703 - loss: 0.6837 - val_accuracy: 0.5706 - val_loss: 0.6837
# Epoch 9/10
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.5693 - loss: 0.6840 - val_accuracy: 0.5706 - val_loss: 0.6834

# %% [markdown]
# # 14. Evaluasi LSTM

# %% [markdown]
# Prediksi probabilitas:

# %%
start_pred = time.time()

y_pred_lstm_prob = lstm_model.predict(X_val_pad)
y_pred_lstm = (y_pred_lstm_prob > 0.5).astype(int).reshape(-1)

end_pred = time.time()
lstm_inference_time = end_pred - start_pred
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %% [markdown]
# Hitung metrik:

# %%
lstm_accuracy = accuracy_score(y_val, y_pred_lstm)
lstm_precision = precision_score(y_val, y_pred_lstm)
lstm_recall = recall_score(y_val, y_pred_lstm)
lstm_f1 = f1_score(y_val, y_pred_lstm)

print("LSTM Results")
print("Accuracy:", lstm_accuracy)
print("Precision:", lstm_precision)
print("Recall:", lstm_recall)
print("F1-score:", lstm_f1)
print("Training Time:", lstm_train_time)
print("Inference Time:", lstm_inference_time)
# Out:
# LSTM Results
# Accuracy: 0.5705843729481287
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# Training Time: 135.26953506469727
# Inference Time: 1.3322269916534424
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Classification report:

# %%
print(classification_report(y_val, y_pred_lstm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73       869
#            1       0.00      0.00      0.00       654
#
#     accuracy                           0.57      1523
#    macro avg       0.29      0.50      0.36      1523
# weighted avg       0.33      0.57      0.41      1523
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # 15. Visualisasi Training LSTM

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('LSTM Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('LSTM Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 16. Perbandingan Semua Model

# %%
results = pd.DataFrame({
    'Model': [
        'TF-IDF Unigram + Logistic Regression',
        'TF-IDF Unigram-Bigram + Linear SVM',
        'TF-IDF Unigram-Bigram + Multinomial NB',
        'Embedding + LSTM'
    ],
    'Accuracy': [
        lr_accuracy,
        svm_accuracy,
        nb_accuracy,
        lstm_accuracy
    ],
    'Precision': [
        lr_precision,
        svm_precision,
        nb_precision,
        lstm_precision
    ],
    'Recall': [
        lr_recall,
        svm_recall,
        nb_recall,
        lstm_recall
    ],
    'F1-score': [
        lr_f1,
        svm_f1,
        nb_f1,
        lstm_f1
    ],
    'Training Time': [
        lr_train_time,
        svm_train_time,
        nb_train_time,
        lstm_train_time
    ],
    'Inference Time': [
        lr_inference_time,
        svm_inference_time,
        nb_inference_time,
        lstm_inference_time
    ]
})

results
# Out:
#                                     Model  Accuracy  Precision    Recall  \
# 0    TF-IDF Unigram + Logistic Regression  0.818779   0.838710  0.715596
# 1      TF-IDF Unigram-Bigram + Linear SVM  0.798424   0.778491  0.741590
# 2  TF-IDF Unigram-Bigram + Multinomial NB  0.818779   0.881048  0.668196
# 3                        Embedding + LSTM  0.570584   0.000000  0.000000
#
#    F1-score  Training Time  Inference Time
# 0  0.772277       0.205560        0.004449
# 1  0.759593       0.035980        0.001154
# 2  0.760000       0.007204        0.001998
# 3  0.000000     135.269535        1.332227

# %% [markdown]
# Urutkan berdasarkan F1-score:

# %%
results.sort_values(by='F1-score', ascending=False)
# Out:
#                                     Model  Accuracy  Precision    Recall  \
# 0    TF-IDF Unigram + Logistic Regression  0.818779   0.838710  0.715596
# 2  TF-IDF Unigram-Bigram + Multinomial NB  0.818779   0.881048  0.668196
# 1      TF-IDF Unigram-Bigram + Linear SVM  0.798424   0.778491  0.741590
# 3                        Embedding + LSTM  0.570584   0.000000  0.000000
#
#    F1-score  Training Time  Inference Time
# 0  0.772277       0.205560        0.004449
# 2  0.760000       0.007204        0.001998
# 1  0.759593       0.035980        0.001154
# 3  0.000000     135.269535        1.332227

# %% [markdown]
# Visualisasi F1-score:

# %%
sns.barplot(data=results, x='F1-score', y='Model')
plt.title('Perbandingan F1-score Model')
plt.show()

# %% [markdown]
# # 17. Confusion Matrix Model Terbaik

# %%
cm = confusion_matrix(y_val, y_pred_lr)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - TF-IDF Unigram + Logistic Regression')
plt.show()

# %% [markdown]
# # 18. Error Analysis Logistic Regression

# %%
error_lr = pd.DataFrame({
    'text': X_val.values,
    'actual': y_val.values,
    'predicted': y_pred_lr
})

error_lr = error_lr[error_lr['actual'] != error_lr['predicted']]
error_lr.head(10)
# Out:
#                                                  text  actual  predicted
# 5   hollywood movie about trapped miners released ...       1          0
# 6          thu aug gmt utc millcityio theramin sirens       1          0
# 7        i cant drown my demons they know how to swim       1          0
# 13  we need these plants in the pacific during the...       1          0
# 14  if firefighters acted like cops theyd drive ar...       0          1
# 16  it looks like a mudslide poor thing greatbriti...       1          0
# 22  on the flip side im at walmart and there is a ...       1          0
# 24  maybe we should call israel and tell them were...       0          1
# 27  i agree with certain cultural appropriation th...       1          0
# 29  the dress memes have officially exploded on th...       1          0

# %% [markdown]
# Tampilkan contoh salah klasifikasi:

# %%
for i, row in error_lr.head(5).iterrows():
    print("Tweet:", row['text'])
    print("Actual:", row['actual'])
    print("Predicted:", row['predicted'])
    print("-" * 80)
# Out:
# Tweet: hollywood movie about trapped miners released in chile the hollywood movie about trapped miners starring
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: thu aug gmt utc millcityio theramin sirens
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: i cant drown my demons they know how to swim
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: we need these plants in the pacific during the cyclone seasons it would help
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: if firefighters acted like cops theyd drive around shooting a flamethrower at burning buildings
# Actual: 0
# Predicted: 1
# --------------------------------------------------------------------------------

# %% [markdown]
# # 19. Error Analysis Linear SVM

# %%
error_svm = pd.DataFrame({
    'text': X_val.values,
    'actual': y_val.values,
    'predicted': y_pred_svm
})

error_svm = error_svm[error_svm['actual'] != error_svm['predicted']]
error_svm.head(10)
# Out:
#                                                  text  actual  predicted
# 0   step one get that mass murderers portrait off ...       0          1
# 5   hollywood movie about trapped miners released ...       1          0
# 7        i cant drown my demons they know how to swim       1          0
# 10                          rip the world its burning       0          1
# 14  if firefighters acted like cops theyd drive ar...       0          1
# 20  ignition knock detonation sensorsenso standard ks       0          1
# 22  on the flip side im at walmart and there is a ...       1          0
# 24  maybe we should call israel and tell them were...       0          1
# 27  i agree with certain cultural appropriation th...       1          0
# 29  the dress memes have officially exploded on th...       1          0

# %%
for i, row in error_svm.head(10).iterrows():
    print("Tweet:", row['text'])
    print("Actual:", row['actual'])
    print("Predicted:", row['predicted'])
    print("-" * 80)
# Out:
# Tweet: step one get that mass murderers portrait off the yuan
# Actual: 0
# Predicted: 1
# --------------------------------------------------------------------------------
# Tweet: hollywood movie about trapped miners released in chile the hollywood movie about trapped miners starring
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: i cant drown my demons they know how to swim
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: rip the world its burning
# Actual: 0
# Predicted: 1
# --------------------------------------------------------------------------------
# Tweet: if firefighters acted like cops theyd drive around shooting a flamethrower at burning buildings
# Actual: 0
# Predicted: 1
# --------------------------------------------------------------------------------
# Tweet: ignition knock detonation sensorsenso standard ks
# Actual: 0
# Predicted: 1
# --------------------------------------------------------------------------------
# Tweet: on the flip side im at walmart and there is a bomb and everyone had to evacuate so stay tuned if i blow up or not
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: maybe we should call israel and tell them were sorry are pres has sold them down the river to annihilation
# Actual: 0
# Predicted: 1
# --------------------------------------------------------------------------------
# Tweet: i agree with certain cultural appropriation things but honestly if u looked at my house it screams appropriation bc buddhas and stuff
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: the dress memes have officially exploded on the internet
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# # 20. Error Analysis LSTM

# %%
error_lstm = pd.DataFrame({
    'text': X_val.values,
    'actual': y_val.values,
    'predicted': y_pred_lstm
})

error_lstm = error_lstm[error_lstm['actual'] != error_lstm['predicted']]
error_lstm.head(10)
# Out:
#                                                  text  actual  predicted
# 2   how little boy affected the people in hiroshim...       1          0
# 5   hollywood movie about trapped miners released ...       1          0
# 6          thu aug gmt utc millcityio theramin sirens       1          0
# 7        i cant drown my demons they know how to swim       1          0
# 12  something frightening is happening to the weat...       1          0
# 13  we need these plants in the pacific during the...       1          0
# 15  dear in the name of humanityi apologized to hi...       1          0
# 16  it looks like a mudslide poor thing greatbriti...       1          0
# 17  families to sue over legionnaires disease outb...       1          0
# 18  still and box alarm for the train derailment a...       1          0

# %%
for i, row in error_lstm.head(10).iterrows():
    print("Tweet:", row['text'])
    print("Actual:", row['actual'])
    print("Predicted:", row['predicted'])
    print("-" * 80)
# Out:
# Tweet: how little boy affected the people in hiroshima eyewitness testimonials
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: hollywood movie about trapped miners released in chile the hollywood movie about trapped miners starring
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: thu aug gmt utc millcityio theramin sirens
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: i cant drown my demons they know how to swim
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: something frightening is happening to the weather in the middle east
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: we need these plants in the pacific during the cyclone seasons it would help
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: dear in the name of humanityi apologized to hiroshima survivorsr u ready to do sojapan nuclearweapons
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: it looks like a mudslide poor thing greatbritishbakeoff
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: families to sue over legionnaires disease outbreak in edinburgh bbc news
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------
# Tweet: still and box alarm for the train derailment at st and calumet struck out on the orders of chicagoscanner
# Actual: 1
# Predicted: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# # 21. Bandingkan Error TF-IDF vs LSTM

# %% [markdown]
# Untuk melihat tweet mana yang salah di TF-IDF tetapi benar di LSTM:

# %%
comparison_error = pd.DataFrame({
    'text': X_val.values,
    'actual': y_val.values,
    'pred_lr': y_pred_lr,
    'pred_svm': y_pred_svm,
    'pred_lstm': y_pred_lstm
})

# %% [markdown]
# Tweet yang salah di SVM tapi benar di LSTM:

# %%
svm_wrong_lstm_correct = comparison_error[
    (comparison_error['pred_svm'] != comparison_error['actual']) &
    (comparison_error['pred_lstm'] == comparison_error['actual'])
]

svm_wrong_lstm_correct.head(10)
# Out:
#                                                  text  actual  pred_lr  \
# 0   step one get that mass murderers portrait off ...       0        0
# 10                          rip the world its burning       0        0
# 14  if firefighters acted like cops theyd drive ar...       0        1
# 20  ignition knock detonation sensorsenso standard ks       0        0
# 24  maybe we should call israel and tell them were...       0        1
# 34                          slicker than an oil spill       0        1
# 58  article by michael jackman at metro times detr...       0        1
# 64  look i have collapsed after attempting to munc...       0        1
# 78  s things she looks in a significant other beau...       0        1
# 80  i hope it rains throughout the whole weekend i...       0        0
#
#     pred_svm  pred_lstm
# 0          1          0
# 10         1          0
# 14         1          0
# 20         1          0
# 24         1          0
# 34         1          0
# 58         1          0
# 64         1          0
# 78         1          0
# 80         1          0

# %% [markdown]
# Tweet yang benar di SVM tapi salah di LSTM:

# %%
svm_correct_lstm_wrong = comparison_error[
    (comparison_error['pred_svm'] == comparison_error['actual']) &
    (comparison_error['pred_lstm'] != comparison_error['actual'])
]

svm_correct_lstm_wrong.head(10)
# Out:
#                                                  text  actual  pred_lr  \
# 2   how little boy affected the people in hiroshim...       1        1
# 6          thu aug gmt utc millcityio theramin sirens       1        0
# 12  something frightening is happening to the weat...       1        1
# 13  we need these plants in the pacific during the...       1        0
# 15  dear in the name of humanityi apologized to hi...       1        1
# 16  it looks like a mudslide poor thing greatbriti...       1        0
# 17  families to sue over legionnaires disease outb...       1        1
# 18  still and box alarm for the train derailment a...       1        1
# 26  bomb head explosive decisions dat produced mor...       1        1
# 28  suicide bomber kills in saudi security site mo...       1        1
#
#     pred_svm  pred_lstm
# 2          1          0
# 6          1          0
# 12         1          0
# 13         1          0
# 15         1          0
# 16         1          0
# 17         1          0
# 18         1          0
# 26         1          0
# 28         1          0

# %% [markdown]
# # 23. Membuat Submission File Kaggle

# %%
X_test = test_df['clean_text']
X_test_tfidf = tfidf_uni.transform(X_test)

test_pred = lr_model.predict(X_test_tfidf)

submission = pd.DataFrame({
    'id': test_df['id'],
    'target': test_pred
})

submission.to_csv('submission.csv', index=False)

from google.colab import files
files.download('submission.csv')
